# %%
counter = 10
while counter > 0:
    print("Counter is at:", counter)
    counter -= 1
# Out:
# Counter is at: 10
# Counter is at: 9
# Counter is at: 8
# Counter is at: 7
# Counter is at: 6
# Counter is at: 5
# Counter is at: 4
# Counter is at: 3
# Counter is at: 2
# Counter is at: 1

# %%
# infinite loop example
counter = 10
while counter > 0:
    print("Counter is at:", counter)
# Out:
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# Counter is at: 10
# ...

# %%
exit = ""
while exit != "exit":
    print("my name is arman")
    exit = input("Type 'exit' to stop the loop: ")
    print("You typed:", exit)
# Out:
# my name is arman
# You typed: ali
# my name is arman
# You typed: exit

# %%
exit = ""
while exit.lower() != "yes":
    user_input = input("what animal do you want?")
    if user_input.lower() == "cow":
        print("A cow goes moo.")
    elif user_input.lower() == "A Lesser Spotted lemur":
        print("Ummm...the Lesser Spotter Lemur goes awooga.")
    else: 
        print("I don't know that animal sound. Try again.")
    
    exit = input("Do you want to exit? ")
# Out:
# A cow goes moo.
